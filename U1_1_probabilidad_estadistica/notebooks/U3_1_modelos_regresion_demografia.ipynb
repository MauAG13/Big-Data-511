# %% [markdown]
# # Práctica: Comparación de modelos de regresión
#
# **Materia:** Tópicos de Big Data
# **Tema:** Introducción al aprendizaje supervisado mediante modelos de regresión
# **Herramientas:** Python · Jupyter Notebook · Pandas · NumPy · Matplotlib · Scikit-learn
#
# ---
#
# ## 1. Objetivo
#
# Construir diferentes modelos de aprendizaje supervisado para realizar **proyecciones del número de nacimientos y defunciones** de un país, utilizando datos históricos.
#
# Durante la práctica se implementarán y compararán visualmente tres modelos:
#
# 1. Regresión lineal
# 2. Regresión polinomial
# 3. Random Forest Regressor
#
# Al finalizar, podrás observar cómo **diferentes modelos generan predicciones diferentes utilizando exactamente los mismos datos**.
#
# > **Nota:** En esta práctica **no** se realizará todavía la evaluación formal de los modelos. La evaluación mediante métricas se realizará en la siguiente sesión.
#
# ---
#
# ## 2. Dataset
#
# Utilizaremos información de **Our World in Data (OWID)** sobre nacimientos y defunciones, que incluye datos históricos y proyecciones hasta el año 2100.
#
# Fuente: *Our World in Data – Births and deaths projected to 2100* (basado en las estimaciones y proyecciones de la ONU).
#
# El dataset contiene información por **país (o región) y año**.

# %% [markdown]
# # PARTE 1. Importar las bibliotecas
#
# En esta práctica utilizaremos:
#
# * **Pandas** para trabajar con el dataset.
# * **NumPy** para trabajar con arreglos y preparar datos.
# * **Matplotlib** para visualizar los datos y las predicciones.
# * **Scikit-learn** para construir los modelos de Machine Learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # PARTE 2. Cargar el dataset
#
# ## 3. Cargar los datos
#
# Leemos el archivo CSV directamente desde la página de OWID.
#
# > **Si no hay internet (o la descarga falla):** descarga el CSV desde la URL de la celda siguiente, guárdalo en la misma carpeta que este notebook con el nombre `births-and-deaths-projected-to-2100.csv` y vuelve a ejecutar la celda. El código lo detecta automáticamente.

# %%
url_fuente = "https://ourworldindata.org/grapher/births-and-deaths-projected-to-2100.csv?v=1&csvType=full&useColumnShortNames=true"

try:
    df_datos = pd.read_csv(
        url_fuente,
        storage_options={
            "User-Agent": "Our World In Data data fetch/1.0"
        }
    )
except Exception as err:
    print("No fue posible descargar el archivo desde internet:", err)
    print("Se utilizará el archivo local 'births-and-deaths-projected-to-2100.csv'")
    df_datos = pd.read_csv("births-and-deaths-projected-to-2100.csv")

df_datos.head()
# Out:
#         entity code  year  deaths__sex_all__age_all__variant_estimates  \
# 0  Afghanistan  AFG  1950                                     290972.0
# 1  Afghanistan  AFG  1951                                     288752.0
# 2  Afghanistan  AFG  1952                                     288059.0
# 3  Afghanistan  AFG  1953                                     287712.0
# 4  Afghanistan  AFG  1954                                     289189.0
#
#    deaths__sex_all__age_all__variant_medium__projected  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    births__sex_all__age_all__variant_estimates  \
# 0                                     383985.0
# 1                                     391002.0
# 2                                     397663.0
# 3                                     404666.0
# 4                                     410428.0
#
#    births__sex_all__age_all__variant_medium__projected
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ## 4. Explorar el dataset
#
# Observemos la estructura del `DataFrame`.

# %%
print("Dimensiones (filas, columnas):", df_datos.shape)
print()
print("Columnas:")
for col in df_datos.columns:
    print("  -", col)
# Out:
# Dimensiones (filas, columnas): (39562, 7)
#
# Columnas:
#   - entity
#   - code
#   - year
#   - deaths__sex_all__age_all__variant_estimates
#   - deaths__sex_all__age_all__variant_medium__projected
#   - births__sex_all__age_all__variant_estimates
#   - births__sex_all__age_all__variant_medium__projected

# %%
df_datos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39562 entries, 0 to 39561
# Data columns (total 7 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   entity                                               39562 non-null  str
#  1   code                                                 38354 non-null  str
#  2   year                                                 39562 non-null  int64
#  3   deaths__sex_all__age_all__variant_estimates          18944 non-null  float64
#  4   deaths__sex_all__age_all__variant_medium__projected  19712 non-null  float64
#  5   births__sex_all__age_all__variant_estimates          19166 non-null  float64
#  6   births__sex_all__age_all__variant_medium__projected  19943 non-null  float64
# dtypes: float64(4), int64(1), str(2)
# memory usage: 2.1 MB

# %%
df_datos.head(10)
# Out:
#         entity code  year  deaths__sex_all__age_all__variant_estimates  \
# 0  Afghanistan  AFG  1950                                     290972.0
# 1  Afghanistan  AFG  1951                                     288752.0
# 2  Afghanistan  AFG  1952                                     288059.0
# 3  Afghanistan  AFG  1953                                     287712.0
# 4  Afghanistan  AFG  1954                                     289189.0
# 5  Afghanistan  AFG  1955                                     286725.0
# 6  Afghanistan  AFG  1956                                     286654.0
# 7  Afghanistan  AFG  1957                                     286114.0
# 8  Afghanistan  AFG  1958                                     285911.0
# 9  Afghanistan  AFG  1959                                     285500.0
#
#    deaths__sex_all__age_all__variant_medium__projected  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    births__sex_all__age_all__variant_estimates  \
# 0                                     383985.0
# 1                                     391002.0
# 2                                     397663.0
# 3                                     404666.0
# 4                                     410428.0
# 5                                     417650.0
# 6                                     425071.0
# 7                                     432044.0
# 8                                     439867.0
# 9                                     447510.0
#
#    births__sex_all__age_all__variant_medium__projected
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# Revisemos las entidades disponibles:

# %%
print("Número de entidades:", df_datos["entity"].nunique())
df_datos["entity"].unique()
# Out:
# Número de entidades: 262
# <StringArray>
# [      'Afghanistan',            'Africa',       'Africa (UN)',
#            'Albania',           'Algeria',    'American Samoa',
#      'Americas (UN)',           'Andorra',            'Angola',
#           'Anguilla',
#  ...
#            'Vanuatu',           'Vatican',         'Venezuela',
#            'Vietnam', 'Wallis and Futuna',    'Western Sahara',
#              'World',             'Yemen',            'Zambia',
#           'Zimbabwe']
# Length: 262, dtype: str

# %% [markdown]
# ### Pregunta
#
# **¿Cuál es la unidad de observación de cada fila del dataset?**
#
# *Respuesta:*
# Cada fila representa el registro de un país o región en un año específico.

# %% [markdown]
# ## 5. Preparar los nombres de las columnas
#
# Al explorar el dataset notamos dos cosas:
#
# 1. Los nombres de las columnas son largos y difíciles de escribir.
# 2. Los **datos históricos** (`..._variant_estimates`) y las **proyecciones de la ONU** (`..._variant_medium__projected`) vienen en **columnas separadas**. Cuando una fila es histórica, la columna de proyección está vacía (`NaN`), y viceversa.
#
# Vamos a renombrar las columnas y a crear dos columnas unificadas, `births` y `deaths`, que contengan el dato histórico cuando existe y la proyección de OWID cuando no.

# %%
df_datos = df_datos.rename(columns={
    "entity": "Entity",
    "code": "Code",
    "year": "Year",
    "births__sex_all__age_all__variant_estimates": "births_estimates",
    "births__sex_all__age_all__variant_medium__projected": "births_projected",
    "deaths__sex_all__age_all__variant_estimates": "deaths_estimates",
    "deaths__sex_all__age_all__variant_medium__projected": "deaths_projected",
})


df_datos.head()
# Out:
#         Entity Code  Year  deaths_estimates  deaths_projected  \
# 0  Afghanistan  AFG  1950          290972.0               NaN
# 1  Afghanistan  AFG  1951          288752.0               NaN
# 2  Afghanistan  AFG  1952          288059.0               NaN
# 3  Afghanistan  AFG  1953          287712.0               NaN
# 4  Afghanistan  AFG  1954          289189.0               NaN
#
#    births_estimates  births_projected
# 0          383985.0               NaN
# 1          391002.0               NaN
# 2          397663.0               NaN
# 3          404666.0               NaN
# 4          410428.0               NaN

# %%
df_raw = df_datos.copy()
df_raw.head(3)
# Out:
#         Entity Code  Year  deaths_estimates  deaths_projected  \
# 0  Afghanistan  AFG  1950          290972.0               NaN
# 1  Afghanistan  AFG  1951          288752.0               NaN
# 2  Afghanistan  AFG  1952          288059.0               NaN
#
#    births_estimates  births_projected
# 0          383985.0               NaN
# 1          391002.0               NaN
# 2          397663.0               NaN

# %%
# Columna unificada: dato histórico si existe; si no, la proyección de OWID
df_datos["births"] = df_datos["births_estimates"].fillna(df_datos["births_projected"])
df_datos["deaths"] = df_datos["deaths_estimates"].fillna(df_datos["deaths_projected"])
df_datos.head()
# Out:
#         Entity Code  Year  deaths_estimates  deaths_projected  \
# 0  Afghanistan  AFG  1950          290972.0               NaN
# 1  Afghanistan  AFG  1951          288752.0               NaN
# 2  Afghanistan  AFG  1952          288059.0               NaN
# 3  Afghanistan  AFG  1953          287712.0               NaN
# 4  Afghanistan  AFG  1954          289189.0               NaN
#
#    births_estimates  births_projected    births    deaths
# 0          383985.0               NaN  383985.0  290972.0
# 1          391002.0               NaN  391002.0  288752.0
# 2          397663.0               NaN  397663.0  288059.0
# 3          404666.0               NaN  404666.0  287712.0
# 4          410428.0               NaN  410428.0  289189.0

# %% [markdown]
# # PARTE 3. Seleccionar un país
#
# ## 6. Seleccionar México
#
# Para esta práctica utilizaremos México.

# %%
pais_seleccionado = "Mexico"

df_mex = df_datos[df_datos["Entity"] == pais_seleccionado]

df_mex.head()
# Out:
#        Entity Code  Year  deaths_estimates  deaths_projected  \
# 22801  Mexico  MEX  1950          596771.0               NaN
# 22802  Mexico  MEX  1951          588791.0               NaN
# 22803  Mexico  MEX  1952          582415.0               NaN
# 22804  Mexico  MEX  1953          565876.0               NaN
# 22805  Mexico  MEX  1954          552321.0               NaN
#
#        births_estimates  births_projected     births    deaths
# 22801         1358501.0               NaN  1358501.0  596771.0
# 22802         1392106.0               NaN  1392106.0  588791.0
# 22803         1423352.0               NaN  1423352.0  582415.0
# 22804         1454762.0               NaN  1454762.0  565876.0
# 22805         1488719.0               NaN  1488719.0  552321.0

# %%
print("Rango de años:", df_mex["Year"].min(), "-", df_mex["Year"].max())
print("Número de filas:", df_mex.shape[0])
# Out:
# Rango de años: 1950 - 2100
# Número de filas: 151

# %% [markdown]
# ## 7. Revisar las variables disponibles
#
# Identifica las columnas correspondientes a: **año**, **nacimientos** y **defunciones**.

# %%
df_mex.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'deaths_estimates', 'deaths_projected',
#        'births_estimates', 'births_projected', 'births', 'deaths'],
#       dtype='str')

# %% [markdown]
# Para esta práctica utilizaremos:
#
# ```text
# Year
# births
# deaths
# ```

# %% [markdown]
# # PARTE 4. Explorar visualmente los datos
#
# ## 8. Nacimientos a través del tiempo

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    df_mex["Year"],
    df_mex["births"]
)

plt.title("Nacimientos en México")
plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.grid()
plt.show()

# %% [markdown]
# ## 9. Defunciones a través del tiempo

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    df_mex["Year"],
    df_mex["deaths"]
)

plt.title("Defunciones en México")
plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.grid()
plt.show()

# %% [markdown]
# ### Preguntas de observación
#
# 1. ¿Los nacimientos presentan una tendencia constante?
# 2. ¿Las defunciones presentan una tendencia constante?
# 3. ¿Las dos variables parecen seguir el mismo comportamiento?
# 4. ¿Observas cambios en la tendencia a través del tiempo?
#
# *Respuestas:*
# 1. No, van subiendo fuerte desde 1950 hasta llegar a 1990 y a partir de ahí empiezan a bajar de manera continua.
# 2. No, al inicio se mantienen en niveles bajos pero con los años van en aumento, viéndose un pico bastante marcado en 2020 y 2021 por la pandemia.
# 3. No, se comportan muy distinto: los nacimientos subieron y luego comenzaron a caer, mientras que las defunciones muestran una tendencia que va en aumento.
# 4. Sí, en los nacimientos se nota un cambio claro por 1990 cuando dejan de subir y bajan. En defunciones se aprecia cómo suben con mayor velocidad en los últimos años y el brinco por el COVID.

# %% [markdown]
# # PARTE 5. Separar datos históricos y proyectados
#
# ## 10. Identificar el punto de separación
#
# El dataset contiene **datos históricos** y **proyecciones**. Antes de separarlos, verifiquemos dónde termina uno y empieza el otro:

# %%
ultimo_anio_hist = df_mex.loc[df_mex["births_estimates"].notna(), "Year"].max()
primer_anio_proy = df_mex.loc[df_mex["births_projected"].notna(), "Year"].min()

print("Último año con dato histórico:", ultimo_anio_hist)
print("Primer año con proyección de OWID:", primer_anio_proy)
# Out:
# Último año con dato histórico: 2023
# Primer año con proyección de OWID: 2024

# %% [markdown]
# Para esta práctica utilizaremos como punto de separación el **año 2023**. Creamos dos `DataFrames`:

# %%
df_hist = df_mex[
    df_mex["Year"] <= 2023
]

df_proy = df_mex[
    df_mex["Year"] > 2023
]

print(df_hist.head(3))
print(df_proy.head(3))
# Out:
#        Entity Code  Year  deaths_estimates  deaths_projected  \
# 22801  Mexico  MEX  1950          596771.0               NaN
# 22802  Mexico  MEX  1951          588791.0               NaN
# 22803  Mexico  MEX  1952          582415.0               NaN
#
#        births_estimates  births_projected     births    deaths
# 22801         1358501.0               NaN  1358501.0  596771.0
# 22802         1392106.0               NaN  1392106.0  588791.0
# 22803         1423352.0               NaN  1423352.0  582415.0
#        Entity Code  Year  deaths_estimates  deaths_projected  \
# 22875  Mexico  MEX  2024               NaN          813823.0
# 22876  Mexico  MEX  2025               NaN          829063.0
# 22877  Mexico  MEX  2026               NaN          844431.0
#
#        births_estimates  births_projected     births    deaths
# 22875               NaN         2023623.0  2023623.0  813823.0
# 22876               NaN         2003673.0  2003673.0  829063.0
# 22877               NaN         1989217.0  1989217.0  844431.0

# %%
print("Histórico  ->", df_hist.shape, "| años:", df_hist["Year"].min(), "a", df_hist["Year"].max())
print("Proyectado ->", df_proy.shape, "| años:", df_proy["Year"].min(), "a", df_proy["Year"].max())
# Out:
# Histórico  -> (74, 9) | años: 1950 a 2023
# Proyectado -> (77, 9) | años: 2024 a 2100

# %% [markdown]
# Comprobemos que no haya valores faltantes en las variables que vamos a utilizar para entrenar:

# %%
df_hist[["Year", "births", "deaths"]].isna().sum()
# Out:
# Year      0
# births    0
# deaths    0
# dtype: int64

# %% [markdown]
# # PARTE 6. Preparar las variables para Machine Learning
#
# ## 11. Definir X e y
#
# Para nuestro primer modelo utilizaremos:
#
# * **X:** año → la **variable predictora**
# * **y:** número de nacimientos → la **variable objetivo**

# %%
X = df_hist[["Year"]]
y_nac = df_hist["births"]

# %%
X.head()
# Out:
#        Year
# 22801  1950
# 22802  1951
# 22803  1952
# 22804  1953
# 22805  1954

# %%
y_nac.head()
# Out:
# 22801    1358501.0
# 22802    1392106.0
# 22803    1423352.0
# 22804    1454762.0
# 22805    1488719.0
# Name: births, dtype: float64

# %% [markdown]
# ## 12. Convertir los datos a NumPy
#
# Obtenemos los valores como arreglos de NumPy:

# %%
X_matriz = X.to_numpy()
y_matriz = y_nac.to_numpy()

print("X_matriz.shape:", X_matriz.shape)
print("y_matriz.shape:", y_matriz.shape)
# Out:
# X_matriz.shape: (74, 1)
# y_matriz.shape: (74,)

# %%
type(X_matriz), type(y_matriz)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %% [markdown]
# ### Observación
#
# Scikit-learn espera normalmente que las variables predictoras tengan la forma:
#
# ```text
# (número de observaciones, número de variables)
# ```
# Es decir, que scikit-learn interpreta X como una tabla de datos.
#
# Por eso `X` tiene **dos dimensiones**, mientras que `y` tiene una sola.
#
# En nuestro ejemplo tenemos:
#
# 74 observaciones (registros).
#
# 1 variable predictora: año (estas son las caracteristicas o atributos usadas para la predicción).
#
# 1 variable objetivo: nacimientos (valor que deseamos predecir).

# %% [markdown]
# # PARTE 7. Modelo 1 – Regresión lineal
#
# ## 13. Crear el modelo

# %%
reg_lineal = LinearRegression()

# %% [markdown]
# ## 14. Entrenar el modelo
#
# Utilizamos los datos históricos para entrenar el modelo.

# %%
reg_lineal.fit(X, y_nac)
# Out:
# LinearRegression()

# %% [markdown]
# Una regresión lineal aprende una recta `y = a·x + b`. Veamos qué valores aprendió:

# %%
print("Pendiente (a):", reg_lineal.coef_[0])
print("Intercepto (b):", reg_lineal.intercept_)
# Out:
# Pendiente (a): 8510.803983709733
# Intercepto (b): -14733373.127152897

# %% [markdown]
# ## 15. Realizar predicciones
#
# Utilizamos el modelo para estimar los nacimientos correspondientes a los **años históricos**.

# %%
pred_lineal_hist = reg_lineal.predict(X)

pred_lineal_hist[:10]
# Out:
# array([1862694.64108108, 1871205.44506479, 1879716.2490485 ,
#        1888227.05303221, 1896737.85701592, 1905248.66099963,
#        1913759.46498334, 1922270.26896705, 1930781.07295076,
#        1939291.87693447])

# %% [markdown]
# ## 16. Realizar proyecciones hasta 2100
#
# Creamos los años para los que queremos generar **nuestras propias proyecciones**.

# %%
anios_fut = np.arange(2024, 2101).reshape(-1, 1)

print("Forma:", anios_fut.shape)
anios_fut[:10]
# Out:
# Forma: (77, 1)
# array([[2024],
#        [2025],
#        [2026],
#        [2027],
#        [2028],
#        [2029],
#        [2030],
#        [2031],
#        [2032],
#        [2033]])

# %% [markdown]
# > **Detalle técnico:** entrenamos el modelo con `X`, que es un `DataFrame` con una columna llamada `Year`. Scikit-learn recuerda ese nombre, así que para predecir también debemos entregarle un `DataFrame` con una columna `Year`. Si le pasáramos un arreglo de NumPy "a secas" mostraría una advertencia (*UserWarning: X does not have valid feature names*). Por eso convertimos los años futuros a `DataFrame`.

# %%
X_fut = pd.DataFrame(anios_fut, columns=["Year"])

X_fut.head()
# Out:
#    Year
# 0  2024
# 1  2025
# 2  2026
# 3  2027
# 4  2028

# %%
pred_lineal_fut = reg_lineal.predict(X_fut)

# %%
print(pred_lineal_fut[:10])
# Out:
# [2492494.1358756  2501004.93985931 2509515.74384302 2518026.54782673
#  2526537.35181044 2535048.15579415 2543558.95977786 2552069.76376157
#  2560580.56774528 2569091.37172899]

# %% [markdown]
# # PARTE 8. Visualizar la regresión lineal
#
# ## 17. Comparar datos históricos y predicciones

# %%
plt.figure(figsize=(12, 6))

plt.scatter(
    df_hist["Year"],
    df_hist["births"],
    label="Datos históricos",
    alpha=0.6
)

# Ajuste del modelo sobre los años históricos
plt.plot(
    df_hist["Year"],
    pred_lineal_hist,
    color="tab:orange",
    label="Regresión lineal (ajuste histórico)"
)

# Proyección hacia el futuro
plt.plot(
    anios_fut.flatten(),
    pred_lineal_fut,
    color="tab:orange",
    linestyle="--",
    label="Regresión lineal (proyección)"
)

plt.title("Proyección de nacimientos – Regresión lineal")
plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Observación
#
# Analiza cómo continúa la tendencia histórica cuando utilizamos una **función lineal**. ¿Qué pasa con los valores hacia el año 2100?

# %% [markdown]
# # PARTE 9. Modelo 2 – Regresión polinomial
#
# ## 18. Crear variables polinomiales
#
# La regresión lineal solamente puede representar una relación **lineal** entre las variables. Ahora construiremos variables polinomiales para permitir **curvas**. Utilizaremos un polinomio de **grado 2**:
#
# $$y = a \cdot x^2 + b \cdot x + c$$

# %%
poly_transform = PolynomialFeatures(
    degree=2,
    include_bias=False
)

# %% [markdown]
# Transformamos `X`:

# %%
X_polinomial = poly_transform.fit_transform(X)

X_polinomial[:5]
# Out:
# array([[1.950000e+03, 3.802500e+06],
#        [1.951000e+03, 3.806401e+06],
#        [1.952000e+03, 3.810304e+06],
#        [1.953000e+03, 3.814209e+06],
#        [1.954000e+03, 3.818116e+06]])

# %% [markdown]
# Observa que ahora cada año tiene **dos columnas**: el año (`x`) y el año al cuadrado (`x²`).
#
# ## 19. Crear y entrenar el modelo polinomial
#
# Seguimos utilizando `LinearRegression`; lo único que cambió son las **variables de entrada**.

# %%
reg_poly = LinearRegression()

reg_poly.fit(
    X_polinomial,
    y_nac
)
# Out:
# LinearRegression()

# %% [markdown]
# ## 20. Generar predicciones históricas

# %%
pred_poly_hist = reg_poly.predict(
    X_polinomial
)

# %% [markdown]
# ## 21. Generar proyecciones hasta 2100
#
# Transformamos los años futuros utilizando **el mismo objeto `poly`** con el que transformamos los datos de entrenamiento.

# %%
anios_poly_fut = poly_transform.transform(
    X_fut
)

pred_poly_fut = reg_poly.predict(
    anios_poly_fut
)

# %% [markdown]
# # PARTE 10. Visualizar la regresión polinomial
#
# ## 22. Graficar las predicciones

# %%
plt.figure(figsize=(12, 6))

plt.scatter(
    df_hist["Year"],
    df_hist["births"],
    label="Datos históricos",
    alpha=0.6
)

plt.plot(
    df_hist["Year"],
    pred_poly_hist,
    color="tab:green",
    label="Regresión polinomial (ajuste histórico)"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_fut,
    color="tab:green",
    linestyle="--",
    label="Regresión polinomial (proyección)"
)

plt.title("Proyección de nacimientos – Regresión polinomial")
plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Observación
#
# Compara el comportamiento de esta gráfica con el modelo de regresión lineal. ¿Se ajusta mejor a los datos históricos? ¿Qué ocurre con la proyección hacia el año 2100? ¿Los valores que predice tienen sentido para un número de nacimientos?

# %% [markdown]
# # PARTE 11. Modelo 3 – Random Forest
#
# ## 23. Crear el modelo
#
# Un **Random Forest** está formado por muchos árboles de decisión. Utilizaremos `RandomForestRegressor`.

# %%
bosque_rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# %% [markdown]
# ## 24. Entrenar el modelo

# %%
bosque_rf.fit(
    X,
    y_nac
)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ## 25. Generar predicciones históricas

# %%
pred_rf_hist = bosque_rf.predict(X)

# %% [markdown]
# ## 26. Generar proyecciones futuras

# %%
pred_rf_fut = bosque_rf.predict(
    X_fut
)

# %% [markdown]
# # PARTE 12. Visualizar Random Forest
#
# ## 27. Graficar las predicciones

# %%
plt.figure(figsize=(12, 6))

plt.scatter(
    df_hist["Year"],
    df_hist["births"],
    label="Datos históricos",
    alpha=0.6
)

plt.plot(
    df_hist["Year"],
    pred_rf_hist,
    color="tab:red",
    label="Random Forest (ajuste histórico)"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_fut,
    color="tab:red",
    linestyle="--",
    label="Random Forest (proyección)"
)

plt.title("Proyección de nacimientos – Random Forest")
plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Observación
#
# Fíjate en dos cosas: (1) qué tan bien sigue el modelo los datos históricos y (2) qué sucede con la línea después de 2023. ¿Continúa la tendencia? ¿Por qué crees que sucede esto? Investiga.

# %% [markdown]
# # PARTE 13. Comparar los tres modelos
#
# ## 28. Graficar los tres modelos
#
# Construimos una gráfica que permita comparar directamente los resultados.
#
# > Si la regresión polinomial genera valores muy extremos y no permite ver bien las demás curvas, puedes limitar el eje vertical agregando, por ejemplo, `plt.ylim(0, 3_500_000)` antes de `plt.show()`.

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    df_hist["Year"],
    df_hist["births"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_fut.flatten(),
    pred_lineal_fut,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_fut,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_fut,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar nacimientos en México"
)

plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # PARTE 14. Repetir el proceso para defunciones
#
# Hasta este momento construimos modelos para predecir **nacimientos**. Ahora repetiremos el mismo proceso para **defunciones**.
#
# ## 29. Preparar la variable objetivo
#
# La variable predictora sigue siendo `X` (el año). Solo cambia la variable objetivo:

# %%
y_def = df_hist["deaths"]

# %% [markdown]
# ## 30. Regresión lineal para defunciones

# %%
reg_lin_def = LinearRegression()

reg_lin_def.fit(
    X,
    y_def
)

pred_lineal_def = reg_lin_def.predict(
    X_fut
)

# %% [markdown]
# ## 31. Regresión polinomial para defunciones
#
# Utilizamos nuevamente las variables construidas con `PolynomialFeatures` (`X_poly` y `anios_futuros_poly`).

# %%
reg_poly_def = LinearRegression()

reg_poly_def.fit(
    X_polinomial,
    y_def
)

pred_poly_def = reg_poly_def.predict(
    anios_poly_fut
)

# %% [markdown]
# ## 32. Random Forest para defunciones

# %%
bosque_rf_def = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

bosque_rf_def.fit(
    X,
    y_def
)

pred_rf_def = bosque_rf_def.predict(
    X_fut
)

# %% [markdown]
# # PARTE 15. Comparar las predicciones de defunciones
#
# ## 33. Visualizar los tres modelos

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    df_hist["Year"],
    df_hist["deaths"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_fut.flatten(),
    pred_lineal_def,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_def,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_def,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar defunciones en México"
)

plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # PARTE 16. Comparar nuestros modelos con las proyecciones de OWID
#
# Finalmente, agregamos a las gráficas las **proyecciones proporcionadas por OWID** (las de la ONU, escenario medio). Estas proyecciones no se obtienen ajustando una recta a la serie histórica: se construyen con modelos demográficos que consideran fecundidad, mortalidad y estructura por edad de la población.
#
# ## 34. Nacimientos: ML vs OWID

# %%
plt.figure(figsize=(14, 7))

plt.plot(
    df_proy["Year"],
    df_proy["births"],
    color="black",
    linewidth=2.5,
    label="Proyección OWID"
)

plt.plot(
    anios_fut.flatten(),
    pred_lineal_fut,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_fut,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_fut,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Proyecciones de nacimientos: ML vs OWID"
)

plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 35. Defunciones: ML vs OWID
#
# Repetimos el ejercicio para defunciones.

# %%
plt.figure(figsize=(14, 7))

plt.plot(
    df_proy["Year"],
    df_proy["deaths"],
    color="black",
    linewidth=2.5,
    label="Proyección OWID"
)

plt.plot(
    anios_fut.flatten(),
    pred_lineal_def,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_def,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_def,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Proyecciones de defunciones: ML vs OWID"
)

plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 36. Resumen numérico (opcional)
#
# A veces es útil ver los números y no solo la gráfica. Esta tabla muestra lo que predice cada modelo para algunos años seleccionados:

# %%
anios_resumen = [2030, 2050, 2075, 2100]
idx_anios = anios_fut.flatten()


def construir_tabla(datos_owid, mod_lineal, mod_poly, mod_rf):
    tabla_comparativa = pd.DataFrame(
        {
            "OWID": datos_owid.set_index("Year").reindex(idx_anios).to_numpy().ravel(),
            "Regresión lineal": mod_lineal,
            "Regresión polinomial": mod_poly,
            "Random Forest": mod_rf,
        },
        index=idx_anios
    )
    tabla_comparativa.index.name = "Año"
    return tabla_comparativa.loc[anios_resumen]


print("NACIMIENTOS")
display(
    construir_tabla(
        df_proy[["Year", "births"]],
        pred_lineal_fut,
        pred_poly_fut,
        pred_rf_fut
    ).style.format("{:,.0f}")
)

print("DEFUNCIONES")
display(
    construir_tabla(
        df_proy[["Year", "deaths"]],
        pred_lineal_def,
        pred_poly_def,
        pred_rf_def
    ).style.format("{:,.0f}")
)
# Out:
# NACIMIENTOS
# <style type="text/css">
# </style>
# <table id="T_0279c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0279c_level0_col0" class="col_heading level0 col0" >OWID</th>
#       <th id="T_0279c_level0_col1" class="col_heading level0 col1" >Regresión lineal</th>
#       <th id="T_0279c_level0_col2" class="col_heading level0 col2" >Regresión polinomial</th>
#       <th id="T_0279c_level0_col3" class="col_heading level0 col3" >Random Forest</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Año</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0279c_level0_row0" class="row_heading level0 row0" >2030</th>
#       <td id="T_0279c_row0_col0" class="data row0 col0" >1,934,285</td>
#       <td id="T_0279c_row0_col1" class="data row0 col1" >2,543,559</td>
#       <td id="T_0279c_row0_col2" class="data row0 col2" >1,672,155</td>
#       <td id="T_0279c_row0_col3" class="data row0 col3" >2,054,207</td>
#     </tr>
#     <tr>
#       <th id="T_0279c_level0_row1" class="row_heading level0 row1" >2050</th>
#       <td id="T_0279c_row1_col0" class="data row1 col0" >1,643,767</td>
#       <td id="T_0279c_row1_col1" class="data row1 col1" >2,713,775</td>
#       <td id="T_0279c_row1_col2" class="data row1 col2" >543,760</td>
#       <td id="T_0279c_row1_col3" class="data row1 col3" >2,054,207</td>
#     </tr>
#     <tr>
#       <th id="T_0279c_level0_row2" class="row_heading level0 row2" >2075</th>
#       <td id="T_0279c_row2_col0" class="data row2 col0" >1,340,246</td>
#       <td id="T_0279c_row2_col1" class="data row2 col1" >2,926,545</td>
#       <td id="T_0279c_row2_col2" class="data row2 col2" >-1,549,414</td>
#       <td id="T_0279c_row2_col3" class="data row2 col3" >2,054,207</td>
#     </tr>
#     <tr>
#       <th id="T_0279c_level0_row3" class="row_heading level0 row3" >2100</th>
#       <td id="T_0279c_row3_col0" class="data row3 col0" >1,098,210</td>
#       <td id="T_0279c_row3_col1" class="data row3 col1" >3,139,315</td>
#       <td id="T_0279c_row3_col2" class="data row3 col2" >-4,401,123</td>
#       <td id="T_0279c_row3_col3" class="data row3 col3" >2,054,207</td>
#     </tr>
#   </tbody>
# </table>
# DEFUNCIONES
# <style type="text/css">
# </style>
# <table id="T_2f751">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f751_level0_col0" class="col_heading level0 col0" >OWID</th>
#       <th id="T_2f751_level0_col1" class="col_heading level0 col1" >Regresión lineal</th>
#       <th id="T_2f751_level0_col2" class="col_heading level0 col2" >Regresión polinomial</th>
#       <th id="T_2f751_level0_col3" class="col_heading level0 col3" >Random Forest</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Año</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f751_level0_row0" class="row_heading level0 row0" >2030</th>
#       <td id="T_2f751_row0_col0" class="data row0 col0" >907,843</td>
#       <td id="T_2f751_row0_col1" class="data row0 col1" >726,810</td>
#       <td id="T_2f751_row0_col2" class="data row0 col2" >1,019,007</td>
#       <td id="T_2f751_row0_col3" class="data row0 col3" >869,570</td>
#     </tr>
#     <tr>
#       <th id="T_2f751_level0_row1" class="row_heading level0 row1" >2050</th>
#       <td id="T_2f751_row1_col0" class="data row1 col0" >1,291,889</td>
#       <td id="T_2f751_row1_col1" class="data row1 col1" >799,521</td>
#       <td id="T_2f751_row1_col2" class="data row1 col2" >1,527,163</td>
#       <td id="T_2f751_row1_col3" class="data row1 col3" >869,570</td>
#     </tr>
#     <tr>
#       <th id="T_2f751_level0_row2" class="row_heading level0 row2" >2075</th>
#       <td id="T_2f751_row2_col0" class="data row2 col0" >1,685,181</td>
#       <td id="T_2f751_row2_col1" class="data row2 col1" >890,408</td>
#       <td id="T_2f751_row2_col2" class="data row2 col2" >2,391,272</td>
#       <td id="T_2f751_row2_col3" class="data row2 col3" >869,570</td>
#     </tr>
#     <tr>
#       <th id="T_2f751_level0_row3" class="row_heading level0 row3" >2100</th>
#       <td id="T_2f751_row3_col0" class="data row3 col0" >1,793,462</td>
#       <td id="T_2f751_row3_col1" class="data row3 col1" >981,296</td>
#       <td id="T_2f751_row3_col2" class="data row3 col2" >3,509,731</td>
#       <td id="T_2f751_row3_col3" class="data row3 col3" >869,570</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # PARTE 17. Reflexión
#
# Responde las siguientes preguntas en esta misma celda (haz doble clic para editarla).
#
# ### 1.
# ¿Qué diferencia observaste entre la regresión lineal, la regresión polinomial y Random Forest?
#
# *Respuesta:*
# - Regresión lineal: Dibuja una línea recta constante sin importar que la tendencia cambie; para nacimientos sigue subiendo y da datos fuera de la realidad para 2100.
# - Regresión polinomial: Sigue muy bien la forma de los datos históricos, pero a futuro cae tan rápido que termina calculando nacimientos negativos, lo cual es imposible.
# - Random Forest: Se adapta muy bien a los datos pasados, pero para el futuro se estanca y repite el último valor como una línea horizontal fija.
#
# ### 2.
# ¿Por qué los tres modelos generan predicciones diferentes si utilizaron los mismos datos históricos?
#
# *Respuesta:*
# Porque cada algoritmo aprende y proyecta de forma distinta: la regresión lineal busca trazar una línea recta, la polinomial acomoda una curva matemática, y Random Forest divide los datos en rangos con árboles de decisión en lugar de calcular una fórmula continua.
#
# ### 3.
# ¿Qué modelo produjo una tendencia más cercana visualmente a las proyecciones de OWID?
#
# *Respuesta:*
# En nacimientos, la regresión polinomial se parece más a la proyección de OWID en las primeras décadas (como hasta 2040) antes de irse a números negativos. En defunciones, la lineal y la polinomial se acercan mucho mejor al aumento que marca OWID, mientras que Random Forest se queda totalmente plano y no sirve para proyectar.
#
# ### 4.
# ¿El modelo que visualmente parece acercarse más a las proyecciones de OWID necesariamente es el mejor modelo? Explica.
#
# *Respuesta:*
# No necesariamente. Que se parezca en una parte de la gráfica puede ser casualidad de la forma de la curva (por ejemplo, la polinomial luego da valores absurdos). Para decir que un modelo es bueno hay que medir su error numéricamente, además de considerar que OWID utiliza datos de población reales (como fertilidad y edades) y no solo el año.
#
# ### 5.
# ¿Qué comportamiento observaste en las predicciones de Random Forest para los años posteriores a 2023?
#
# *Respuesta:*
# Se queda totalmente plano, como una línea horizontal recta que repite siempre el mismo número. Esto sucede porque este modelo no sabe continuar tendencias fuera de lo que ya vio, así que a cualquier año futuro le asigna el promedio del último dato histórico que aprendió.
#
# ### 6.
# ¿Por qué debemos tener cuidado al utilizar un modelo entrenado con datos históricos para realizar predicciones hasta el año 2100?
#
# *Respuesta:*
# Porque son casi 80 años en el futuro usando muy pocos datos del pasado y con una sola variable (el año). En la vida real la población cambia por temas de salud, economía o pandemias imprevistas que una ecuación no puede prever, lo que lleva a resultados irreales como valores negativos o líneas congeladas.

# %% [markdown]
# # PARTE 18. Conceptos clave
#
# Al finalizar la práctica, debes poder identificar:
#
# | Concepto | Significado |
# |---|---|
# | **Variable predictora** | Variable utilizada por el modelo para generar una predicción |
# | **Variable objetivo** | Variable que queremos predecir |
# | **Entrenamiento** | Proceso mediante el cual el modelo aprende a partir de los datos |
# | **Predicción** | Resultado generado por el modelo |
# | **Regresión lineal** | Modelo que representa una relación lineal |
# | **Regresión polinomial** | Extensión que permite representar relaciones curvas |
# | **Random Forest** | Modelo basado en múltiples árboles de decisión |
# | **Extrapolación** | Generación de predicciones fuera del rango de datos utilizados para entrenar el modelo |
#
# > **Importante:** En esta práctica solamente hemos **construido y utilizado** los modelos. En la siguiente práctica aprenderemos a **evaluar su desempeño mediante métricas**, para determinar qué tan bien están realizando sus predicciones.

# %% [markdown]
# # Ejercicio 1: Extraer el país de China

# %%
datos_china = df_datos[df_datos["Entity"] == "China"]

china_hist = datos_china[
    datos_china["Year"] <= 2023
]

X_ch = china_hist[["Year"]]
y_nac_ch = china_hist["births"]
y_def_ch = china_hist["deaths"]

poly_ch = PolynomialFeatures(
    degree=2,
    include_bias=False
)

X_poly_ch = poly_ch.fit_transform(X_ch)
anios_poly_fut_ch = poly_ch.transform(X_fut)

# %% [markdown]
# ## Nacimientos en China

# %%
reg_lin_ch_nac = LinearRegression()
reg_lin_ch_nac.fit(X_ch, y_nac_ch)
pred_lin_ch_nac = reg_lin_ch_nac.predict(X_fut)

reg_poly_ch_nac = LinearRegression()
reg_poly_ch_nac.fit(X_poly_ch, y_nac_ch)
pred_poly_ch_nac = reg_poly_ch_nac.predict(
    anios_poly_fut_ch
)

bosque_ch_nac = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
bosque_ch_nac.fit(X_ch, y_nac_ch)
pred_rf_ch_nac = bosque_ch_nac.predict(X_fut)

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    china_hist["Year"],
    china_hist["births"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_fut.flatten(),
    pred_lin_ch_nac,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_ch_nac,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_ch_nac,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar nacimientos en China"
)

plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Defunciones en China

# %%
reg_lin_ch_def = LinearRegression()
reg_lin_ch_def.fit(X_ch, y_def_ch)
pred_lin_ch_def = reg_lin_ch_def.predict(X_fut)

reg_poly_ch_def = LinearRegression()
reg_poly_ch_def.fit(X_poly_ch, y_def_ch)
pred_poly_ch_def = reg_poly_ch_def.predict(
    anios_poly_fut_ch
)

bosque_ch_def = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
bosque_ch_def.fit(X_ch, y_def_ch)
pred_rf_ch_def = bosque_ch_def.predict(X_fut)

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    china_hist["Year"],
    china_hist["deaths"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_fut.flatten(),
    pred_lin_ch_def,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_ch_def,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_ch_def,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar defunciones en China"
)

plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Ejercicio 2: Extraer nacimientos / defunciones a partir de 1980 en México

# %%
mex_desde_1980 = df_mex[
    (df_mex["Year"] >= 1980) & (df_mex["Year"] <= 2023)
]

X_hist_1980 = mex_desde_1980[["Year"]]
y_nac_1980 = mex_desde_1980["births"]
y_def_1980 = mex_desde_1980["deaths"]

poly_feat_1980 = PolynomialFeatures(
    degree=2,
    include_bias=False
)

X_poly_1980 = poly_feat_1980.fit_transform(X_hist_1980)
anios_poly_fut_1980 = poly_feat_1980.transform(X_fut)

# %% [markdown]
# ## Nacimientos a partir de 1980 en México

# %%
reg_lin_1980_nac = LinearRegression()
reg_lin_1980_nac.fit(X_hist_1980, y_nac_1980)
pred_lin_1980_nac = reg_lin_1980_nac.predict(X_fut)

reg_poly_1980_nac = LinearRegression()
reg_poly_1980_nac.fit(X_poly_1980, y_nac_1980)
pred_poly_1980_nac = reg_poly_1980_nac.predict(
    anios_poly_fut_1980
)

bosque_1980_nac = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
bosque_1980_nac.fit(X_hist_1980, y_nac_1980)
pred_rf_1980_nac = bosque_1980_nac.predict(X_fut)

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    mex_desde_1980["Year"],
    mex_desde_1980["births"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_fut.flatten(),
    pred_lin_1980_nac,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_1980_nac,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_1980_nac,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar nacimientos en México (a partir de 1980)"
)

plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Defunciones a partir de 1980 en México

# %%
reg_lin_1980_def = LinearRegression()
reg_lin_1980_def.fit(X_hist_1980, y_def_1980)
pred_lin_1980_def = reg_lin_1980_def.predict(X_fut)

reg_poly_1980_def = LinearRegression()
reg_poly_1980_def.fit(X_poly_1980, y_def_1980)
pred_poly_1980_def = reg_poly_1980_def.predict(
    anios_poly_fut_1980
)

bosque_1980_def = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
bosque_1980_def.fit(X_hist_1980, y_def_1980)
pred_rf_1980_def = bosque_1980_def.predict(X_fut)

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    mex_desde_1980["Year"],
    mex_desde_1980["deaths"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_fut.flatten(),
    pred_lin_1980_def,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_1980_def,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_1980_def,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar defunciones en México (a partir de 1980)"
)

plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Ejercicio 3: Extraer nacimientos / defunciones a partir de 2000 en México

# %%
mex_desde_2000 = df_mex[
    (df_mex["Year"] >= 2000) & (df_mex["Year"] <= 2023)
]

X_hist_2000 = mex_desde_2000[["Year"]]
y_nac_2000 = mex_desde_2000["births"]
y_def_2000 = mex_desde_2000["deaths"]

poly_feat_2000 = PolynomialFeatures(
    degree=2,
    include_bias=False
)

X_poly_2000 = poly_feat_2000.fit_transform(X_hist_2000)
anios_poly_fut_2000 = poly_feat_2000.transform(X_fut)

# %% [markdown]
# ## Nacimientos a partir de 2000 en México

# %%
reg_lin_2000_nac = LinearRegression()
reg_lin_2000_nac.fit(X_hist_2000, y_nac_2000)
pred_lin_2000_nac = reg_lin_2000_nac.predict(X_fut)

reg_poly_2000_nac = LinearRegression()
reg_poly_2000_nac.fit(X_poly_2000, y_nac_2000)
pred_poly_2000_nac = reg_poly_2000_nac.predict(
    anios_poly_fut_2000
)

bosque_2000_nac = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
bosque_2000_nac.fit(X_hist_2000, y_nac_2000)
pred_rf_2000_nac = bosque_2000_nac.predict(X_fut)

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    mex_desde_2000["Year"],
    mex_desde_2000["births"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_fut.flatten(),
    pred_lin_2000_nac,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_2000_nac,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_2000_nac,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar nacimientos en México (a partir de 2000)"
)

plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Defunciones a partir de 2000 en México

# %%
reg_lin_2000_def = LinearRegression()
reg_lin_2000_def.fit(X_hist_2000, y_def_2000)
pred_lin_2000_def = reg_lin_2000_def.predict(X_fut)

reg_poly_2000_def = LinearRegression()
reg_poly_2000_def.fit(X_poly_2000, y_def_2000)
pred_poly_2000_def = reg_poly_2000_def.predict(
    anios_poly_fut_2000
)

bosque_2000_def = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
bosque_2000_def.fit(X_hist_2000, y_def_2000)
pred_rf_2000_def = bosque_2000_def.predict(X_fut)

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    mex_desde_2000["Year"],
    mex_desde_2000["deaths"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_fut.flatten(),
    pred_lin_2000_def,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_fut.flatten(),
    pred_poly_2000_def,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_fut.flatten(),
    pred_rf_2000_def,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar defunciones en México (a partir de 2000)"
)

plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()
